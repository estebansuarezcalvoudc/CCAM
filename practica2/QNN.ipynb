# %% [markdown]
# Autor: Esteban Suárez Calvo

# %%
from datetime import timedelta
from time import time

import numpy as np
from qiskit import QuantumCircuit
from qiskit.circuit.library import n_local, z_feature_map, zz_feature_map
from qiskit_aer import AerSimulator
from qiskit_ibm_runtime import Sampler
from qiskit_machine_learning.algorithms.classifiers import VQC
from qiskit_machine_learning.optimizers import (
    COBYLA,
    NELDER_MEAD,
    POWELL,
    SPSA,
    CRS,
    DIRECT_L,
)
from qiskit_machine_learning.utils import algorithm_globals
from sklearn.datasets import load_breast_cancer
from sklearn.decomposition import PCA
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.svm import SVC

# %% [markdown]
# # CCAM - Práctica 2: Redes Neuronales Cuánticas

# %% [markdown]
# Antes de empezar, fijaremos la semilla aleatoria, de manera que los resultados obtenidos en el notebook sean reproducibles.

# %%
algorithm_globals.random_seed = 1

# %% [markdown]
# ## 1.Preprocesado
#
# ### Normalización del dataset
#
# Normalizamos el dataset utilizando la normalización MinMax.

# %%
data = load_breast_cancer()
X = data.data
y = data.target
X = MinMaxScaler().fit_transform(X)
print(f"Número de características = {X.shape[1]}")
# Out:
# Número de características = 30

# %% [markdown]
# ### Reducción de dimensionalidad
#
# Reducimos la dimensionalidad del dataset utilizando una reducción PCA. De no hacerlo, necesitaríamos un total de 30 qubits, pues tenemos 30 características, y cada una se representa con un qubit. El problema está en que, aunque 30 qubits pueden no parecer demasiados, puede suponer un costo computacional bastante elevado el tener que emularlos.
#
# Sin embargo, reducir la dimensionalidad tiene también su parte negativa, y es que al reducirla, estas dimensiones colapsan en menos, lo que hace que las clases que, anteriormente, podrían ser separables, puedan ya no serlo, por lo que debemos de ser cuidadosos y no pasarnos al reducir las dimensiones.

# %%
X = PCA(n_components=12).fit_transform(X)
number_of_features = X.shape[1]
print(f"Nuevo número de características = {number_of_features}")
# Out:
# Nuevo número de características = 12

# %% [markdown]
# ### Dividir el conjunto entre entrenamiento y test

# %%
X_train, X_test, Y_train, Y_test = train_test_split(
    X, y, test_size=0.20, random_state=algorithm_globals.random_seed
)
print(f"Datos de entrenamiento: {len(X_train)}")
print(f"Datos de test: {len(X_test)}")
# Out:
# Datos de entrenamiento: 455
# Datos de test: 114

# %% [markdown]
# ### Clasificación con un SVM
#
# Para comprobar que el problema es resoluble con la reducción de dimensionalidad que hemos aplicado antes, utilizamos un SVM

# %%
svc = SVC()
svc.fit(X_train, Y_train)

train_score = svc.score(X_train, Y_train)
test_score = svc.score(X_test, Y_test)

print(f"SVC en entrenamiento: {train_score}")
print(f"SVC en test: {test_score}")
# Out:
# SVC en entrenamiento: 0.9824175824175824
# SVC en test: 0.9736842105263158

# %% [markdown]
# ## Desarrolla una QNN para predecir la clase de cada caso
#
# A continuación, definimos una función que, dado un `feature_map`, un `ansatz` y un `optimizer` arbitrarios, crea el `VQC` correspondiente y lo entrena. Definimos también un callback para hacer más interactivo el proceso de entrenamiento, de manera que, a cada iteración, se muestre el número de la iteración y el *loss*:

# %%
def train_VQC(feature_map, ansatz, optimizer) -> VQC:
    global X_train, Y_train

    number_of_features = X.shape[1]
    feature_map = zz_feature_map(number_of_features)

    vqc = VQC(
        feature_map=feature_map,
        ansatz=ansatz,
        optimizer=optimizer,
        callback=MyCallback().print_loss,
        sampler=Sampler(AerSimulator()),
    )

    start = time()
    vqc.fit(X_train, Y_train)
    total_time = time() - start
    print(f"Tiempo total de entrenamiento: {timedelta(seconds=total_time)}")

    return vqc


class MyCallback:
    def __init__(self):
        self._loss_history = []

    def print_loss(self, weights, obj_func_eval):
        self._loss_history.append(obj_func_eval)

        iteration = len(self._loss_history)

        print(f"Iteración {iteration} - Loss: {obj_func_eval:.4f}")

# %% [markdown]
# Definimos también una función para poder evaluar el clasificador.

# %%
def evaluate_VQC(vqc: VQC) -> None:
    global X_train, Y_train

    train_score = vqc.score(X_train, Y_train)
    print(f"SVC en entrenamiento: {train_score}")

    test_score = vqc.score(X_test, Y_test)
    print(f"SVC en test: {test_score}")

# %% [markdown]
# Ahora que tenemos una función para crear el `VQC` y para evaluarlo, podemos realizar pruebas con distintos clasificadores y ver que tan bien funcionan.

# %%
feature_map = zz_feature_map(number_of_features)
ansatz = n_local(number_of_features, "ry", "cx", "linear", reps=1)
optimizer = COBYLA(maxiter=50)

vqc = train_VQC(feature_map, ansatz, optimizer)
evaluate_VQC(vqc)
# Out:
# No gradient function provided, creating a gradient function. If your Sampler requires transpilation, please provide a pass manager.
# Iteración 1 - Loss: 0.9883
# Iteración 2 - Loss: 0.9905
# Iteración 3 - Loss: 0.9914
# Iteración 4 - Loss: 0.9873
# Iteración 5 - Loss: 0.9909
# Iteración 6 - Loss: 0.9904
# Iteración 7 - Loss: 0.9869
# Iteración 8 - Loss: 0.9898
# Iteración 9 - Loss: 0.9889
# Iteración 10 - Loss: 0.9877
# Iteración 11 - Loss: 0.9868
# Iteración 12 - Loss: 0.9863
# Iteración 13 - Loss: 0.9870
# Iteración 14 - Loss: 0.9738
# Iteración 15 - Loss: 0.9755
# Iteración 16 - Loss: 0.9753
# Iteración 17 - Loss: 0.9802
# Iteración 18 - Loss: 0.9801
# Iteración 19 - Loss: 0.9755
# Iteración 20 - Loss: 0.9781
# Iteración 21 - Loss: 0.9772
# Iteración 22 - Loss: 0.9785
# Iteración 23 - Loss: 0.9748
# Iteración 24 - Loss: 0.9763
# Iteración 25 - Loss: 0.9731
# Iteración 26 - Loss: 0.9846
# Iteración 27 - Loss: 0.9908
# Iteración 28 - Loss: 0.9667
# Iteración 29 - Loss: 0.9674
# Iteración 30 - Loss: 0.9652
# Iteración 31 - Loss: 0.9648
# Iteración 32 - Loss: 0.9693
# Iteración 33 - Loss: 0.9639
# Iteración 34 - Loss: 0.9652
# Iteración 35 - Loss: 0.9690
# Iteración 36 - Loss: 0.9690
# Iteración 37 - Loss: 0.9652
# Iteración 38 - Loss: 0.9704
# Iteración 39 - Loss: 0.9673
# Iteración 40 - Loss: 0.9690
# Iteración 41 - Loss: 0.9644
# Iteración 42 - Loss: 0.9652
# Iteración 43 - Loss: 0.9648
# Iteración 44 - Loss: 0.9639
# Iteración 45 - Loss: 0.9643
# Iteración 46 - Loss: 0.9639
# Iteración 47 - Loss: 0.9625
# Iteración 48 - Loss: 0.9649
# Iteración 49 - Loss: 0.9667
# Iteración 50 - Loss: 0.9688
# Iteración 51 - Loss: 0.9662
# Iteración 52 - Loss: 0.9638
# Iteración 53 - Loss: 0.9660
# Iteración 54 - Loss: 0.9678
# Iteración 55 - Loss: 0.9622
# Iteración 56 - Loss: 0.9623
# Iteración 57 - Loss: 0.9609
# Iteración 58 - Loss: 0.9647
# Iteración 59 - Loss: 0.9650
# Iteración 60 - Loss: 0.9690
# Iteración 61 - Loss: 0.9632
# Iteración 62 - Loss: 0.9640
# Iteración 63 - Loss: 0.9678
# Iteración 64 - Loss: 0.9688
# Iteración 65 - Loss: 0.9642
# Iteración 66 - Loss: 0.9647
# Iteración 67 - Loss: 0.9697
# Iteración 68 - Loss: 0.9690
# Iteración 69 - Loss: 0.9625
# Iteración 70 - Loss: 0.9650
# Iteración 71 - Loss: 0.9610
# Iteración 72 - Loss: 0.9642
# Iteración 73 - Loss: 0.9688
# Iteración 74 - Loss: 0.9644
# Iteración 75 - Loss: 0.9650
# Iteración 76 - Loss: 0.9640
# Iteración 77 - Loss: 0.9700
# Iteración 78 - Loss: 0.9667
# Iteración 79 - Loss: 0.9639
# Iteración 80 - Loss: 0.9637
# Iteración 81 - Loss: 0.9659
# Iteración 82 - Loss: 0.9655
# Iteración 83 - Loss: 0.9656
# Iteración 84 - Loss: 0.9625
# Iteración 85 - Loss: 0.9645
# Iteración 86 - Loss: 0.9690
# Iteración 87 - Loss: 0.9672
# Iteración 88 - Loss: 0.9693
# Iteración 89 - Loss: 0.9643
# Iteración 90 - Loss: 0.9718
# Iteración 91 - Loss: 0.9654
# Iteración 92 - Loss: 0.9667
# Iteración 93 - Loss: 0.9676
# Iteración 94 - Loss: 0.9629
# Iteración 95 - Loss: 0.9643
# Iteración 96 - Loss: 0.9651
# Iteración 97 - Loss: 0.9667
# Iteración 98 - Loss: 0.9665
# Iteración 99 - Loss: 0.9660
# Iteración 100 - Loss: 0.9686
# Tiempo total de entrenamiento: -1 day, 23:39:13.501926
# SVC en entrenamiento: 0.5868131868131868
# SVC en test: 0.5701754385964912

# %%
feature_map = zz_feature_map(number_of_features)
ansatz = n_local(number_of_features, "ry", "cx", "linear", reps=2)
optimizer = COBYLA(maxiter=50)

vqc = train_VQC(feature_map, ansatz, optimizer)
evaluate_VQC(vqc)
# Out:
# No gradient function provided, creating a gradient function. If your Sampler requires transpilation, please provide a pass manager.
# Iteración 1 - Loss: 0.9978
# Iteración 2 - Loss: 1.0021
# Iteración 3 - Loss: 0.9942
# Iteración 4 - Loss: 0.9929
# Iteración 5 - Loss: 0.9909
# Iteración 6 - Loss: 0.9947
# Iteración 7 - Loss: 0.9907
# Iteración 8 - Loss: 0.9961
# Iteración 9 - Loss: 0.9928
# Iteración 10 - Loss: 0.9919
# Iteración 11 - Loss: 0.9929
# Iteración 12 - Loss: 0.9923
# Iteración 13 - Loss: 0.9922
# Iteración 14 - Loss: 0.9746
# Iteración 15 - Loss: 0.9739
# Iteración 16 - Loss: 0.9725
# Iteración 17 - Loss: 0.9730
# Iteración 18 - Loss: 0.9720
# Iteración 19 - Loss: 0.9709
# Iteración 20 - Loss: 0.9746
# Iteración 21 - Loss: 0.9731
# Iteración 22 - Loss: 0.9711
# Iteración 23 - Loss: 0.9776
# Iteración 24 - Loss: 0.9694
# Iteración 25 - Loss: 0.9725
# Iteración 26 - Loss: 0.9938
# Iteración 27 - Loss: 0.9744
# Iteración 28 - Loss: 0.9729
# Iteración 29 - Loss: 0.9723
# Iteración 30 - Loss: 0.9753
# Iteración 31 - Loss: 0.9716
# Iteración 32 - Loss: 0.9735
# Iteración 33 - Loss: 0.9740
# Iteración 34 - Loss: 0.9700
# Iteración 35 - Loss: 0.9732
# Iteración 36 - Loss: 0.9752
# Iteración 37 - Loss: 0.9762
# Iteración 38 - Loss: 0.9746
# Iteración 39 - Loss: 0.9878
# Iteración 40 - Loss: 0.9764
# Iteración 41 - Loss: 0.9744
# Iteración 42 - Loss: 0.9706
# Iteración 43 - Loss: 0.9721
# Iteración 44 - Loss: 0.9737
# Iteración 45 - Loss: 0.9717
# Iteración 46 - Loss: 0.9680
# Iteración 47 - Loss: 0.9721
# Iteración 48 - Loss: 0.9716
# Iteración 49 - Loss: 0.9712
# Iteración 50 - Loss: 0.9680
# Iteración 51 - Loss: 0.9690
# Iteración 52 - Loss: 0.9806
# Iteración 53 - Loss: 0.9718
# Iteración 54 - Loss: 0.9689
# Iteración 55 - Loss: 0.9727
# Iteración 56 - Loss: 0.9676
# Iteración 57 - Loss: 0.9716
# Iteración 58 - Loss: 0.9684
# Iteración 59 - Loss: 0.9681
# Iteración 60 - Loss: 0.9702
# Iteración 61 - Loss: 0.9695
# Iteración 62 - Loss: 0.9655
# Iteración 63 - Loss: 0.9674
# Iteración 64 - Loss: 0.9711
# Iteración 65 - Loss: 0.9660
# Iteración 66 - Loss: 0.9690
# Iteración 67 - Loss: 0.9626
# Iteración 68 - Loss: 0.9659
# Iteración 69 - Loss: 0.9703
# Iteración 70 - Loss: 0.9626
# Iteración 71 - Loss: 0.9680
# Iteración 72 - Loss: 0.9730
# Iteración 73 - Loss: 0.9692
# Iteración 74 - Loss: 0.9676
# Iteración 75 - Loss: 0.9697
# Iteración 76 - Loss: 0.9685
# Iteración 77 - Loss: 0.9733
# Iteración 78 - Loss: 0.9685
# Iteración 79 - Loss: 0.9673
# Iteración 80 - Loss: 0.9745
# Iteración 81 - Loss: 0.9682
# Iteración 82 - Loss: 0.9715
# Iteración 83 - Loss: 0.9656
# Iteración 84 - Loss: 0.9685
# Iteración 85 - Loss: 0.9699
# Iteración 86 - Loss: 0.9770
# Iteración 87 - Loss: 0.9677
# Iteración 88 - Loss: 0.9706
# Iteración 89 - Loss: 0.9692
# Iteración 90 - Loss: 0.9708
# Iteración 91 - Loss: 0.9690
# Iteración 92 - Loss: 0.9672
# Iteración 93 - Loss: 0.9703
# Iteración 94 - Loss: 0.9659
# Iteración 95 - Loss: 0.9666
# Iteración 96 - Loss: 0.9675
# Iteración 97 - Loss: 0.9696
# Iteración 98 - Loss: 0.9703
# Iteración 99 - Loss: 0.9683
# Iteración 100 - Loss: 0.9693
# Tiempo total de entrenamiento: -1 day, 23:38:21.672631
# SVC en entrenamiento: 0.589010989010989
# SVC en test: 0.5877192982456141

# %%
feature_map = zz_feature_map(number_of_features)
ansatz = n_local(number_of_features, "ry", "cx", "linear", reps=3)
optimizer = COBYLA(maxiter=50)

vqc = train_VQC(feature_map, ansatz, optimizer)
evaluate_VQC(vqc)
# Out:
# No gradient function provided, creating a gradient function. If your Sampler requires transpilation, please provide a pass manager.
# Iteración 1 - Loss: 0.9857
# Iteración 2 - Loss: 0.9927
# Iteración 3 - Loss: 0.9912
# Iteración 4 - Loss: 0.9849
# Iteración 5 - Loss: 0.9855
# Iteración 6 - Loss: 0.9883
# Iteración 7 - Loss: 0.9846
# Iteración 8 - Loss: 0.9905
# Iteración 9 - Loss: 0.9854
# Iteración 10 - Loss: 0.9865
# Iteración 11 - Loss: 0.9855
# Iteración 12 - Loss: 0.9881
# Iteración 13 - Loss: 0.9900
# Iteración 14 - Loss: 0.9961
# Iteración 15 - Loss: 0.9968
# Iteración 16 - Loss: 0.9864
# Iteración 17 - Loss: 0.9874
# Iteración 18 - Loss: 0.9880
# Iteración 19 - Loss: 0.9873
# Iteración 20 - Loss: 0.9885
# Iteración 21 - Loss: 0.9834
# Iteración 22 - Loss: 0.9867
# Iteración 23 - Loss: 0.9856
# Iteración 24 - Loss: 0.9900
# Iteración 25 - Loss: 0.9873
# Iteración 26 - Loss: 1.0014
# Iteración 27 - Loss: 0.9837
# Iteración 28 - Loss: 0.9865
# Iteración 29 - Loss: 0.9849
# Iteración 30 - Loss: 0.9833
# Iteración 31 - Loss: 0.9904
# Iteración 32 - Loss: 0.9860
# Iteración 33 - Loss: 0.9843
# Iteración 34 - Loss: 0.9893
# Iteración 35 - Loss: 0.9845
# Iteración 36 - Loss: 0.9882
# Iteración 37 - Loss: 0.9866
# Iteración 38 - Loss: 1.0000
# Iteración 39 - Loss: 0.9898
# Iteración 40 - Loss: 0.9826
# Iteración 41 - Loss: 0.9862
# Iteración 42 - Loss: 0.9898
# Iteración 43 - Loss: 0.9865
# Iteración 44 - Loss: 0.9875
# Iteración 45 - Loss: 0.9882
# Iteración 46 - Loss: 0.9875
# Iteración 47 - Loss: 0.9879
# Iteración 48 - Loss: 0.9850
# Iteración 49 - Loss: 0.9870
# Iteración 50 - Loss: 0.9932
# Iteración 51 - Loss: 0.9920
# Iteración 52 - Loss: 0.9916
# Iteración 53 - Loss: 0.9907
# Iteración 54 - Loss: 0.9858
# Iteración 55 - Loss: 0.9847
# Iteración 56 - Loss: 0.9866
# Iteración 57 - Loss: 0.9881
# Iteración 58 - Loss: 0.9847
# Iteración 59 - Loss: 0.9880
# Iteración 60 - Loss: 0.9844
# Iteración 61 - Loss: 0.9905
# Iteración 62 - Loss: 0.9881
# Iteración 63 - Loss: 0.9852
# Iteración 64 - Loss: 0.9855
# Iteración 65 - Loss: 0.9891
# Iteración 66 - Loss: 0.9872
# Iteración 67 - Loss: 0.9843
# Iteración 68 - Loss: 0.9871
# Iteración 69 - Loss: 0.9866
# Iteración 70 - Loss: 0.9847
# Iteración 71 - Loss: 0.9886
# Iteración 72 - Loss: 0.9861
# Iteración 73 - Loss: 0.9901
# Iteración 74 - Loss: 0.9862
# Iteración 75 - Loss: 0.9838
# Iteración 76 - Loss: 0.9851
# Iteración 77 - Loss: 0.9831
# Iteración 78 - Loss: 0.9905
# Iteración 79 - Loss: 0.9859
# Iteración 80 - Loss: 0.9881
# Iteración 81 - Loss: 0.9884
# Iteración 82 - Loss: 0.9863
# Iteración 83 - Loss: 0.9839
# Iteración 84 - Loss: 0.9890
# Iteración 85 - Loss: 0.9852
# Iteración 86 - Loss: 0.9895
# Iteración 87 - Loss: 0.9852
# Iteración 88 - Loss: 0.9834
# Iteración 89 - Loss: 0.9881
# Iteración 90 - Loss: 0.9842
# Iteración 91 - Loss: 0.9891
# Iteración 92 - Loss: 0.9857
# Iteración 93 - Loss: 0.9849
# Iteración 94 - Loss: 0.9824
# Iteración 95 - Loss: 0.9840
# Iteración 96 - Loss: 0.9857
# Iteración 97 - Loss: 0.9826
# Iteración 98 - Loss: 0.9861
# Iteración 99 - Loss: 0.9871
# Iteración 100 - Loss: 0.9862
# Tiempo total de entrenamiento: -1 day, 23:37:37.716683
# SVC en entrenamiento: 0.5956043956043956
# SVC en test: 0.543859649122807

# %% [markdown]
# Como podemos observar, modificar las "capas" de la red (`reps`), no produce ninguna diferencia. Por lo tanto, vemos que, para mejorar nuestro clasificador, modificar este parámetro no es relevante.
#
# Vemos también que el número de iteraciones tampoco tiene ninguna relevancia, puesto que en cada iteración el loss obtenido es prácticamente el mismo, por lo que modificar ese hiperparámetro no tendría sentido.
#
# Dada la nula evolución del loss, todo parece indicar a que el problema está en que nos encontramos en una *barren plateau*, una meseta de la cual nos es muy complicado salir, puesto que el optimizador no es capaz de encontrar una dirección en la que descienda el gradiente.

# %%
feature_map = zz_feature_map(number_of_features)
ansatz = n_local(number_of_features, "ry", "cx", "linear")
optimizer = NELDER_MEAD(maxiter=50)

vqc = train_VQC(feature_map, ansatz, optimizer)
evaluate_VQC(vqc)
# Out:
# No gradient function provided, creating a gradient function. If your Sampler requires transpilation, please provide a pass manager.
#
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File ~/miniconda3/envs/ccam-p2/lib/python3.12/site-packages/IPython/core/async_helpers.py:128, in _pseudo_sync_runner(coro)
#     120 """
#     121 A runner that does not really allow async execution, and just advance the coroutine.
#     122
#    (...)    125 Credit to Nathaniel Smith
#     126 """
#     127 try:
# --> 128     coro.send(None)
#     129 except StopIteration as exc:
#     130     return exc.value
#
# File ~/miniconda3/envs/ccam-p2/lib/python3.12/site-packages/IPython/core/interactiveshell.py:3419, in InteractiveShell.run_cell_async(self, raw_cell, store_history, silent, shell_futures, transformed_cell, preprocessing_exc_tuple, cell_id)
#    3414     self.history_manager.store_output(execution_count)
#    3415     if result.error_in_exec:
#    3416         # Store formatted traceback and error details
#    3417         self.history_manager.exceptions[
#    3418             execution_count
# -> 3419         ] = self._format_exception_for_storage(result.error_in_exec)
#    3421 return result
#
# File ~/miniconda3/envs/ccam-p2/lib/python3.12/site-packages/IPython/core/interactiveshell.py:3469, in InteractiveShell._format_exception_for_storage(self, exception, filename, running_compiled_code)
#    3466         stb = evalue._render_traceback_()
#    3467     else:
#    3468         # Otherwise, use InteractiveTB to format the traceback.
# -> 3469         stb = self.InteractiveTB.structured_traceback(
#    3470             etype, evalue, tb, tb_offset=1
#    3471         )
#    3472 except Exception:
#    3473     # In case formatting fails, fallback to Python's built-in formatting.
#    3474     stb = traceback.format_exception(etype, evalue, tb)
#
# File ~/miniconda3/envs/ccam-p2/lib/python3.12/site-packages/IPython/core/ultratb.py:1193, in AutoFormattedTB.structured_traceback(self, etype, evalue, etb, tb_offset, context)
#    1191 else:
#    1192     self.tb = etb
# -> 1193 return FormattedTB.structured_traceback(
#    1194     self, etype, evalue, etb, tb_offset, context
#    1195 )
#
# File ~/miniconda3/envs/ccam-p2/lib/python3.12/site-packages/IPython/core/ultratb.py:1064, in FormattedTB.structured_traceback(self, etype, evalue, etb, tb_offset, context)
#    1061 mode = self.mode
#    1062 if mode in self.verbose_modes:
#    1063     # Verbose modes need a full traceback
# -> 1064     return VerboseTB.structured_traceback(
#    1065         self, etype, evalue, etb, tb_offset, context
#    1066     )
#    1067 elif mode == "Docs":
#    1068     # return DocTB
#    1069     return DocTB(
#    1070         theme_name=self._theme_name,
#    1071         call_pdb=self.call_pdb,
#    (...)   1079         etype, evalue, etb, tb_offset, 1
#    1080     )  # type: ignore[arg-type]
#
# File ~/miniconda3/envs/ccam-p2/lib/python3.12/site-packages/IPython/core/ultratb.py:872, in VerboseTB.structured_traceback(self, etype, evalue, etb, tb_offset, context)
#     863 def structured_traceback(
#     864     self,
#     865     etype: type,
#    (...)    869     context: int = 5,
#     870 ) -> list[str]:
#     871     """Return a nice text document describing the traceback."""
# --> 872     formatted_exceptions: list[list[str]] = self.format_exception_as_a_whole(
#     873         etype, evalue, etb, context, tb_offset
#     874     )
#     876     termsize = min(75, get_terminal_size()[0])
#     877     theme = theme_table[self._theme_name]
#
# File ~/miniconda3/envs/ccam-p2/lib/python3.12/site-packages/IPython/core/ultratb.py:757, in VerboseTB.format_exception_as_a_whole(self, etype, evalue, etb, context, tb_offset)
#     755 assert isinstance(tb_offset, int)
#     756 head = self.prepare_header(str(etype), self.long_header)
# --> 757 records = self.get_records(etb, context, tb_offset) if etb else []
#     759 frames = []
#     760 skipped = 0
#
# File ~/miniconda3/envs/ccam-p2/lib/python3.12/site-packages/IPython/core/ultratb.py:830, in VerboseTB.get_records(self, etb, context, tb_offset)
#     828 while cf is not None:
#     829     try:
# --> 830         mod = inspect.getmodule(cf.tb_frame)
#     831         if mod is not None:
#     832             mod_name = mod.__name__
#
# File ~/miniconda3/envs/ccam-p2/lib/python3.12/inspect.py:1016, in getmodule(object, _filename)
#    1013         f = getabsfile(module)
#    1014         # Always map to the name the module knows itself by
#    1015         modulesbyfile[f] = modulesbyfile[
# -> 1016             os.path.realpath(f)] = module.__name__
#    1017 if file in modulesbyfile:
#    1018     return sys.modules.get(modulesbyfile[file])
#
# File ~/miniconda3/envs/ccam-p2/lib/python3.12/posixpath.py:427, in realpath(filename, strict)
#     424     """Return the canonical path of the specified filename, eliminating any
#     425 symbolic links encountered in the path."""
#     426     filename = os.fspath(filename)
# --> 427     path, ok = _joinrealpath(filename[:0], filename, strict, {})
#     428     return abspath(path)
#
# File ~/miniconda3/envs/ccam-p2/lib/python3.12/posixpath.py:471, in _joinrealpath(path, rest, strict, seen)
#     469 newpath = join(path, name)
#     470 try:
# --> 471     st = os.lstat(newpath)
#     472 except ignored_error:
#     473     is_link = False
#
# KeyboardInterrupt:

# %%
feature_map = zz_feature_map(number_of_features)
ansatz = n_local(number_of_features, "ry", "cx", "linear")
optimizer = POWELL(maxiter=50)

vqc = train_VQC(feature_map, ansatz, optimizer)
evaluate_VQC(vqc)
# Out:
# No gradient function provided, creating a gradient function. If your Sampler requires transpilation, please provide a pass manager.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[33], line 5
#       2 ansatz = n_local(number_of_features, "ry", "cx", "linear")
#       3 optimizer = POWELL(maxiter=50)
# ----> 5 vqc = train_VQC(feature_map, ansatz, optimizer)
#       6 evaluate_VQC(vqc)
#
# Cell In[23], line 19, in train_VQC(feature_map, ansatz, optimizer)
#       9 vqc = VQC(
#      10     feature_map=feature_map,
#      11     ansatz=ansatz,
#    (...)     15     initial_point=initial_point,
#      16 )
#      18 start = time()
# ---> 19 vqc.fit(X_train, Y_train)
#      20 total_time = time() - start
#      21 print(f"Tiempo total de entrenamiento: {timedelta(seconds=total_time)}")
#
# File ~/miniconda3/envs/ccam-p2/lib/python3.12/site-packages/qiskit_machine_learning/algorithms/trainable_model.py:199, in TrainableModel.fit(self, X, y)
#     196 if not self._warm_start:
#     197     self._fit_result = None
# --> 199 self._fit_result = self._fit_internal(X, y)
#     200 return self
#
# File ~/miniconda3/envs/ccam-p2/lib/python3.12/site-packages/qiskit_machine_learning/algorithms/classifiers/vqc.py:195, in VQC._fit_internal(self, X, y)
#     192     self._neural_network.set_interpret(self.interpret, num_classes)
#     194 function = self._create_objective(X, y)
# --> 195 return self._minimize(function)
#
# File ~/miniconda3/envs/ccam-p2/lib/python3.12/site-packages/qiskit_machine_learning/algorithms/trainable_model.py:296, in TrainableModel._minimize(self, function)
#     292     optimizer_result = self._optimizer(  # type: ignore[call-arg]
#     293         fun=objective, x0=initial_point, jac=function.gradient
#     294     )
#     295 else:
# --> 296     optimizer_result = self._optimizer.minimize(
#     297         fun=objective,
#     298         x0=initial_point,
#     299         jac=function.gradient,  # type: ignore[arg-type]
#     300     )
#     301 return optimizer_result
#
# File ~/miniconda3/envs/ccam-p2/lib/python3.12/site-packages/qiskit_machine_learning/optimizers/scipy_optimizer.py:148, in SciPyOptimizer.minimize(self, fun, x0, jac, bounds)
#     145     swapped_deprecated_args = True
#     146     self._options["maxfun"] = self._options.pop("maxiter")
# --> 148 raw_result = minimize(
#     149     fun=fun,
#     150     x0=x0,
#     151     method=self._method,
#     152     jac=jac,
#     153     bounds=bounds,
#     154     options=self._options,
#     155     **self._kwargs,
#     156 )
#     157 if swapped_deprecated_args:
#     158     self._options["maxiter"] = self._options.pop("maxfun")
#
# File ~/miniconda3/envs/ccam-p2/lib/python3.12/site-packages/scipy/optimize/_minimize.py:729, in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     726     res = _minimize_neldermead(fun, x0, args, callback, bounds=bounds,
#     727                                **options)
#     728 elif meth == 'powell':
# --> 729     res = _minimize_powell(fun, x0, args, callback, bounds, **options)
#     730 elif meth == 'cg':
#     731     res = _minimize_cg(fun, x0, args, jac, callback, **options)
#
# File ~/miniconda3/envs/ccam-p2/lib/python3.12/site-packages/scipy/optimize/_optimize.py:3518, in _minimize_powell(func, x0, args, callback, bounds, xtol, ftol, maxiter, maxfev, disp, direc, return_all, **unknown_options)
#    3514     if np.any(lower_bound > x0) or np.any(x0 > upper_bound):
#    3515         warnings.warn("Initial guess is not within the specified bounds",
#    3516                       OptimizeWarning, stacklevel=3)
# -> 3518 fval = func(x)
#    3519 x1 = x.copy()
#    3520 iter = 0
#
# File ~/miniconda3/envs/ccam-p2/lib/python3.12/site-packages/scipy/optimize/_optimize.py:542, in _wrap_scalar_function_maxfun_validation.<locals>.function_wrapper(x, *wrapper_args)
#     540 ncalls[0] += 1
#     541 # A copy of x is sent to the user function (gh13740)
# --> 542 fx = function(np.copy(x), *(wrapper_args + args))
#     543 # Ideally, we'd like to a have a true scalar returned from f(x). For
#     544 # backwards-compatibility, also allow np.array([1.3]),
#     545 # np.array([[1.3]]) etc.
#     546 if not np.isscalar(fx):
#
# File ~/miniconda3/envs/ccam-p2/lib/python3.12/site-packages/qiskit_machine_learning/algorithms/trainable_model.py:271, in TrainableModel._get_objective.<locals>.objective(objective_weights)
#     270 def objective(objective_weights):
# --> 271     objective_value = function.objective(objective_weights)
#     272     if isinstance(self._optimizer, SciPyOptimizer):
#     273         self._callback(objective_weights, objective_value)
#
# File ~/miniconda3/envs/ccam-p2/lib/python3.12/site-packages/qiskit_machine_learning/algorithms/objective_functions.py:191, in OneHotObjectiveFunction.objective(self, weights)
#     189 def objective(self, weights: np.ndarray) -> float:
#     190     # probabilities is of shape (N, num_outputs)
# --> 191     probs = self._neural_network_forward(weights)
#     192     # float(...) is for mypy compliance
#     193     value = float(np.sum(self._loss(probs, self._y)) / self._num_samples)
#
# File ~/miniconda3/envs/ccam-p2/lib/python3.12/site-packages/qiskit_machine_learning/algorithms/objective_functions.py:102, in ObjectiveFunction._neural_network_forward(self, weights)
#      97 # if we get the same weights, we don't compute the forward pass again.
#      98 if self._last_forward_weights is None or (
#      99     not np.all(np.isclose(weights, self._last_forward_weights))
#     100 ):
#     101     # compute forward and cache the results for re-use in backward
# --> 102     self._last_forward = self._neural_network.forward(self._X, weights)
#     103     # a copy avoids keeping a reference to the same array, so we are sure we have
#     104     # different arrays on the next iteration.
#     105     self._last_forward_weights = np.copy(weights)
#
# File ~/miniconda3/envs/ccam-p2/lib/python3.12/site-packages/qiskit_machine_learning/neural_networks/neural_network.py:229, in NeuralNetwork.forward(self, input_data, weights)
#     227 input_, shape = self._validate_input(input_data)
#     228 weights_ = self._validate_weights(weights)
# --> 229 output_data = self._forward(input_, weights_)
#     230 return self._validate_forward_output(output_data, shape)
#
# File ~/miniconda3/envs/ccam-p2/lib/python3.12/site-packages/qiskit_machine_learning/neural_networks/sampler_qnn.py:497, in SamplerQNN._forward(self, input_data, weights)
#     492     raise QiskitMachineLearningError(
#     493         "The accepted estimators are BaseSamplerV1 (deprecated) and BaseSamplerV2; "
#     494         + f"got {type(self.sampler)} instead."
#     495     )
#     496 try:
# --> 497     results = job.result()
#     498 except Exception as exc:
#     499     raise QiskitMachineLearningError(f"Sampler job failed: {exc}") from exc
#
# File ~/miniconda3/envs/ccam-p2/lib/python3.12/site-packages/qiskit/primitives/primitive_job.py:51, in PrimitiveJob.result(self)
#      49 def result(self) -> ResultT:
#      50     self._check_submitted()
# ---> 51     return self._future.result()
#
# File ~/miniconda3/envs/ccam-p2/lib/python3.12/concurrent/futures/_base.py:451, in Future.result(self, timeout)
#     448 elif self._state == FINISHED:
#     449     return self.__get_result()
# --> 451 self._condition.wait(timeout)
#     453 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#     454     raise CancelledError()
#
# File ~/miniconda3/envs/ccam-p2/lib/python3.12/threading.py:355, in Condition.wait(self, timeout)
#     353 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     354     if timeout is None:
# --> 355         waiter.acquire()
#     356         gotit = True
#     357     else:
#
# KeyboardInterrupt:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File ~/miniconda3/envs/ccam-p2/lib/python3.12/site-packages/IPython/core/async_helpers.py:128, in _pseudo_sync_runner(coro)
#     120 """
#     121 A runner that does not really allow async execution, and just advance the coroutine.
#     122
#    (...)    125 Credit to Nathaniel Smith
#     126 """
#     127 try:
# --> 128     coro.send(None)
#     129 except StopIteration as exc:
#     130     return exc.value
#
# File ~/miniconda3/envs/ccam-p2/lib/python3.12/site-packages/IPython/core/interactiveshell.py:3419, in InteractiveShell.run_cell_async(self, raw_cell, store_history, silent, shell_futures, transformed_cell, preprocessing_exc_tuple, cell_id)
#    3414     self.history_manager.store_output(execution_count)
#    3415     if result.error_in_exec:
#    3416         # Store formatted traceback and error details
#    3417         self.history_manager.exceptions[
#    3418             execution_count
# -> 3419         ] = self._format_exception_for_storage(result.error_in_exec)
#    3421 return result
#
# File ~/miniconda3/envs/ccam-p2/lib/python3.12/site-packages/IPython/core/interactiveshell.py:3469, in InteractiveShell._format_exception_for_storage(self, exception, filename, running_compiled_code)
#    3466         stb = evalue._render_traceback_()
#    3467     else:
#    3468         # Otherwise, use InteractiveTB to format the traceback.
# -> 3469         stb = self.InteractiveTB.structured_traceback(
#    3470             etype, evalue, tb, tb_offset=1
#    3471         )
#    3472 except Exception:
#    3473     # In case formatting fails, fallback to Python's built-in formatting.
#    3474     stb = traceback.format_exception(etype, evalue, tb)
#
# File ~/miniconda3/envs/ccam-p2/lib/python3.12/site-packages/IPython/core/ultratb.py:1193, in AutoFormattedTB.structured_traceback(self, etype, evalue, etb, tb_offset, context)
#    1191 else:
#    1192     self.tb = etb
# -> 1193 return FormattedTB.structured_traceback(
#    1194     self, etype, evalue, etb, tb_offset, context
#    1195 )
#
# File ~/miniconda3/envs/ccam-p2/lib/python3.12/site-packages/IPython/core/ultratb.py:1064, in FormattedTB.structured_traceback(self, etype, evalue, etb, tb_offset, context)
#    1061 mode = self.mode
#    1062 if mode in self.verbose_modes:
#    1063     # Verbose modes need a full traceback
# -> 1064     return VerboseTB.structured_traceback(
#    1065         self, etype, evalue, etb, tb_offset, context
#    1066     )
#    1067 elif mode == "Docs":
#    1068     # return DocTB
#    1069     return DocTB(
#    1070         theme_name=self._theme_name,
#    1071         call_pdb=self.call_pdb,
#    (...)   1079         etype, evalue, etb, tb_offset, 1
#    1080     )  # type: ignore[arg-type]
#
# File ~/miniconda3/envs/ccam-p2/lib/python3.12/site-packages/IPython/core/ultratb.py:872, in VerboseTB.structured_traceback(self, etype, evalue, etb, tb_offset, context)
#     863 def structured_traceback(
#     864     self,
#     865     etype: type,
#    (...)    869     context: int = 5,
#     870 ) -> list[str]:
#     871     """Return a nice text document describing the traceback."""
# --> 872     formatted_exceptions: list[list[str]] = self.format_exception_as_a_whole(
#     873         etype, evalue, etb, context, tb_offset
#     874     )
#     876     termsize = min(75, get_terminal_size()[0])
#     877     theme = theme_table[self._theme_name]
#
# File ~/miniconda3/envs/ccam-p2/lib/python3.12/site-packages/IPython/core/ultratb.py:784, in VerboseTB.format_exception_as_a_whole(self, etype, evalue, etb, context, tb_offset)
#     774         frames.append(
#     775             theme_table[self._theme_name].format(
#     776                 [
#    (...)    781             )
#     782         )
#     783         skipped = 0
# --> 784     frames.append(self.format_record(record))
#     785 if skipped:
#     786     frames.append(
#     787         theme_table[self._theme_name].format(
#     788             [
#    (...)    793         )
#     794     )
#
# File ~/miniconda3/envs/ccam-p2/lib/python3.12/site-packages/IPython/core/ultratb.py:659, in VerboseTB.format_record(self, frame_info)
#     656 result += ", " if call else ""
#     657 result += f"{call}\n"
#     658 result += theme_table[self._theme_name].format(
# --> 659     _format_traceback_lines(
#     660         frame_info.lines,
#     661         theme_table[self._theme_name],
#     662         self.has_colors,
#     663         lvals_toks,
#     664     )
#     665 )
#     666 return result
#
# File ~/miniconda3/envs/ccam-p2/lib/python3.12/site-packages/IPython/core/tbtools.py:100, in _format_traceback_lines(lines, theme, has_colors, lvals_toks)
#      97     continue
#      99 lineno = stack_line.lineno
# --> 100 line = stack_line.render(pygmented=has_colors).rstrip("\n") + "\n"
#     101 if stack_line.is_current:
#     102     # This is the line with the error
#     103     pad = numbers_width - len(str(lineno))
#
# File ~/miniconda3/envs/ccam-p2/lib/python3.12/site-packages/stack_data/core.py:391, in Line.render(self, markers, strip_leading_indent, pygmented, escape_html)
#     389 if pygmented and self.frame_info.scope:
#     390     assert_(not markers, ValueError("Cannot use pygmented with markers"))
# --> 391     start_line, lines = self.frame_info._pygmented_scope_lines
#     392     result = lines[self.lineno - start_line]
#     393     if strip_leading_indent:
#
# File ~/miniconda3/envs/ccam-p2/lib/python3.12/site-packages/stack_data/utils.py:145, in cached_property.cached_property_wrapper(self, obj, _cls)
#     142 if obj is None:
#     143     return self
# --> 145 value = obj.__dict__[self.func.__name__] = self.func(obj)
#     146 return value
#
# File ~/miniconda3/envs/ccam-p2/lib/python3.12/site-packages/stack_data/core.py:824, in FrameInfo._pygmented_scope_lines(self)
#     821     ranges = []
#     823 code = atext.get_text(scope)
# --> 824 lines = _pygmented_with_ranges(formatter, code, ranges)
#     826 start_line = self.source.line_range(scope)[0]
#     828 return start_line, lines
#
# File ~/miniconda3/envs/ccam-p2/lib/python3.12/site-packages/stack_data/utils.py:164, in _pygmented_with_ranges(formatter, code, ranges)
#     161             length += len(value)
#     162             yield ttype, value
# --> 164 lexer = MyLexer(stripnl=False)
#     165 try:
#     166     highlighted = pygments.highlight(code, lexer, formatter)
#
# File ~/miniconda3/envs/ccam-p2/lib/python3.12/site-packages/pygments/lexer.py:660, in RegexLexerMeta.__call__(cls, *args, **kwds)
#     658         pass
#     659     else:
# --> 660         cls._tokens = cls.process_tokendef('', cls.get_tokendefs())
#     662 return type.__call__(cls, *args, **kwds)
#
# File ~/miniconda3/envs/ccam-p2/lib/python3.12/site-packages/pygments/lexer.py:599, in RegexLexerMeta.process_tokendef(cls, name, tokendefs)
#     597 tokendefs = tokendefs or cls.tokens[name]
#     598 for state in list(tokendefs):
# --> 599     cls._process_state(tokendefs, processed, state)
#     600 return processed
#
# File ~/miniconda3/envs/ccam-p2/lib/python3.12/site-packages/pygments/lexer.py:563, in RegexLexerMeta._process_state(cls, unprocessed, processed, state)
#     560 if isinstance(tdef, include):
#     561     # it's a state reference
#     562     assert tdef != state, f"circular state reference {state!r}"
# --> 563     tokens.extend(cls._process_state(unprocessed, processed,
#     564                                      str(tdef)))
#     565     continue
#     566 if isinstance(tdef, _inherit):
#     567     # should be processed already, but may not in the case of:
#     568     # 1. the state has no counterpart in any parent
#     569     # 2. the state includes more than one 'inherit'
#
# File ~/miniconda3/envs/ccam-p2/lib/python3.12/site-packages/pygments/lexer.py:563, in RegexLexerMeta._process_state(cls, unprocessed, processed, state)
#     560 if isinstance(tdef, include):
#     561     # it's a state reference
#     562     assert tdef != state, f"circular state reference {state!r}"
# --> 563     tokens.extend(cls._process_state(unprocessed, processed,
#     564                                      str(tdef)))
#     565     continue
#     566 if isinstance(tdef, _inherit):
#     567     # should be processed already, but may not in the case of:
#     568     # 1. the state has no counterpart in any parent
#     569     # 2. the state includes more than one 'inherit'
#
# File ~/miniconda3/envs/ccam-p2/lib/python3.12/site-packages/pygments/lexer.py:579, in RegexLexerMeta._process_state(cls, unprocessed, processed, state)
#     576 assert type(tdef) is tuple, f"wrong rule def {tdef!r}"
#     578 try:
# --> 579     rex = cls._process_regex(tdef[0], rflags, state)
#     580 except Exception as err:
#     581     raise ValueError(f"uncompilable regex {tdef[0]!r} in state {state!r} of {cls!r}: {err}") from err
#
# File ~/miniconda3/envs/ccam-p2/lib/python3.12/site-packages/pygments/lexer.py:507, in RegexLexerMeta._process_regex(cls, regex, rflags, state)
#     505 """Preprocess the regular expression component of a token definition."""
#     506 if isinstance(regex, Future):
# --> 507     regex = regex.get()
#     508 return re.compile(regex, rflags).match
#
# File ~/miniconda3/envs/ccam-p2/lib/python3.12/site-packages/pygments/lexer.py:495, in words.get(self)
#     494 def get(self):
# --> 495     return regex_opt(self.words, prefix=self.prefix, suffix=self.suffix)
#
# File ~/miniconda3/envs/ccam-p2/lib/python3.12/site-packages/pygments/regexopt.py:91, in regex_opt(strings, prefix, suffix)
#      83 """Return a compiled regex that matches any string in the given list.
#      84
#      85 The strings to match must be literal strings, not regexes.  They will be
#    (...)     88 *prefix* and *suffix* are pre- and appended to the final regex.
#      89 """
#      90 strings = sorted(strings)
# ---> 91 return prefix + regex_opt_inner(strings, '(') + suffix
#
# File ~/miniconda3/envs/ccam-p2/lib/python3.12/site-packages/pygments/regexopt.py:77, in regex_opt_inner(strings, open_paren)
#      71     return open_paren \
#      72         + regex_opt_inner(sorted(s[:-slen] for s in strings), '(?:') \
#      73         + escape(suffix[::-1]) + close_paren
#      74 # recurse on common 1-string prefixes
#      75 # print '-> last resort'
#      76 return open_paren + \
# ---> 77     '|'.join(regex_opt_inner(list(group[1]), '')
#      78              for group in groupby(strings, lambda s: s[0] == first[0])) \
#      79     + close_paren
#
# File ~/miniconda3/envs/ccam-p2/lib/python3.12/site-packages/pygments/regexopt.py:77, in <genexpr>(.0)
#      71     return open_paren \
#      72         + regex_opt_inner(sorted(s[:-slen] for s in strings), '(?:') \
#      73         + escape(suffix[::-1]) + close_paren
#      74 # recurse on common 1-string prefixes
#      75 # print '-> last resort'
#      76 return open_paren + \
# ---> 77     '|'.join(regex_opt_inner(list(group[1]), '')
#      78              for group in groupby(strings, lambda s: s[0] == first[0])) \
#      79     + close_paren
#
# File ~/miniconda3/envs/ccam-p2/lib/python3.12/site-packages/pygments/regexopt.py:77, in regex_opt_inner(strings, open_paren)
#      71     return open_paren \
#      72         + regex_opt_inner(sorted(s[:-slen] for s in strings), '(?:') \
#      73         + escape(suffix[::-1]) + close_paren
#      74 # recurse on common 1-string prefixes
#      75 # print '-> last resort'
#      76 return open_paren + \
# ---> 77     '|'.join(regex_opt_inner(list(group[1]), '')
#      78              for group in groupby(strings, lambda s: s[0] == first[0])) \
#      79     + close_paren
#
# File ~/miniconda3/envs/ccam-p2/lib/python3.12/site-packages/pygments/regexopt.py:77, in <genexpr>(.0)
#      71     return open_paren \
#      72         + regex_opt_inner(sorted(s[:-slen] for s in strings), '(?:') \
#      73         + escape(suffix[::-1]) + close_paren
#      74 # recurse on common 1-string prefixes
#      75 # print '-> last resort'
#      76 return open_paren + \
# ---> 77     '|'.join(regex_opt_inner(list(group[1]), '')
#      78              for group in groupby(strings, lambda s: s[0] == first[0])) \
#      79     + close_paren
#
#     [... skipping similar frames: <genexpr> at line 77 (12 times), regex_opt_inner at line 77 (12 times)]
#
# File ~/miniconda3/envs/ccam-p2/lib/python3.12/site-packages/pygments/regexopt.py:77, in regex_opt_inner(strings, open_paren)
#      71     return open_paren \
#      72         + regex_opt_inner(sorted(s[:-slen] for s in strings), '(?:') \
#      73         + escape(suffix[::-1]) + close_paren
#      74 # recurse on common 1-string prefixes
#      75 # print '-> last resort'
#      76 return open_paren + \
# ---> 77     '|'.join(regex_opt_inner(list(group[1]), '')
#      78              for group in groupby(strings, lambda s: s[0] == first[0])) \
#      79     + close_paren
#
# File ~/miniconda3/envs/ccam-p2/lib/python3.12/site-packages/pygments/regexopt.py:77, in <genexpr>(.0)
#      71     return open_paren \
#      72         + regex_opt_inner(sorted(s[:-slen] for s in strings), '(?:') \
#      73         + escape(suffix[::-1]) + close_paren
#      74 # recurse on common 1-string prefixes
#      75 # print '-> last resort'
#      76 return open_paren + \
# ---> 77     '|'.join(regex_opt_inner(list(group[1]), '')
#      78              for group in groupby(strings, lambda s: s[0] == first[0])) \
#      79     + close_paren
#
# File ~/miniconda3/envs/ccam-p2/lib/python3.12/site-packages/pygments/regexopt.py:63, in regex_opt_inner(strings, open_paren)
#      59     plen = len(prefix)
#      60     # we have a prefix for all strings
#      61     # print '-> prefix:', prefix
#      62     return open_paren + escape(prefix) \
# ---> 63         + regex_opt_inner([s[plen:] for s in strings], '(?:') \
#      64         + close_paren
#      65 # is there a suffix?
#      66 strings_rev = [s[::-1] for s in strings]
#
# File ~/miniconda3/envs/ccam-p2/lib/python3.12/site-packages/pygments/regexopt.py:77, in regex_opt_inner(strings, open_paren)
#      71     return open_paren \
#      72         + regex_opt_inner(sorted(s[:-slen] for s in strings), '(?:') \
#      73         + escape(suffix[::-1]) + close_paren
#      74 # recurse on common 1-string prefixes
#      75 # print '-> last resort'
#      76 return open_paren + \
# ---> 77     '|'.join(regex_opt_inner(list(group[1]), '')
#      78              for group in groupby(strings, lambda s: s[0] == first[0])) \
#      79     + close_paren
#
# File ~/miniconda3/envs/ccam-p2/lib/python3.12/site-packages/pygments/regexopt.py:77, in <genexpr>(.0)
#      71     return open_paren \
#      72         + regex_opt_inner(sorted(s[:-slen] for s in strings), '(?:') \
#      73         + escape(suffix[::-1]) + close_paren
#      74 # recurse on common 1-string prefixes
#      75 # print '-> last resort'
#      76 return open_paren + \
# ---> 77     '|'.join(regex_opt_inner(list(group[1]), '')
#      78              for group in groupby(strings, lambda s: s[0] == first[0])) \
#      79     + close_paren
#
# File ~/miniconda3/envs/ccam-p2/lib/python3.12/site-packages/pygments/regexopt.py:57, in regex_opt_inner(strings, open_paren)
#      55         # print '-> only 1-character'
#      56         return open_paren + make_charset(oneletter) + close_paren
# ---> 57 prefix = commonprefix(strings)
#      58 if prefix:
#      59     plen = len(prefix)
#
# File ~/miniconda3/envs/ccam-p2/lib/python3.12/genericpath.py:89, in commonprefix(m)
#      84 # Some people pass in a list of pathname parts to operate in an OS-agnostic
#      85 # fashion; don't try to translate in that case as that's an abuse of the
#      86 # API and they are already doing what they need to be OS-agnostic and so
#      87 # they most likely won't be using an os.PathLike object in the sublists.
#      88 if not isinstance(m[0], (list, tuple)):
# ---> 89     m = tuple(map(os.fspath, m))
#      90 s1 = min(m)
#      91 s2 = max(m)
#
# KeyboardInterrupt:

# %%
feature_map = zz_feature_map(number_of_features)
ansatz = n_local(number_of_features, "ry", "cx", "linear")
optimizer = SPSA(maxiter=50)

vqc = train_VQC(feature_map, ansatz, optimizer)
evaluate_VQC(vqc)
# Out:
# No gradient function provided, creating a gradient function. If your Sampler requires transpilation, please provide a pass manager.
#
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File ~/miniconda3/envs/ccam-p2/lib/python3.12/site-packages/IPython/core/async_helpers.py:128, in _pseudo_sync_runner(coro)
#     120 """
#     121 A runner that does not really allow async execution, and just advance the coroutine.
#     122
#    (...)    125 Credit to Nathaniel Smith
#     126 """
#     127 try:
# --> 128     coro.send(None)
#     129 except StopIteration as exc:
#     130     return exc.value
#
# File ~/miniconda3/envs/ccam-p2/lib/python3.12/site-packages/IPython/core/interactiveshell.py:3419, in InteractiveShell.run_cell_async(self, raw_cell, store_history, silent, shell_futures, transformed_cell, preprocessing_exc_tuple, cell_id)
#    3414     self.history_manager.store_output(execution_count)
#    3415     if result.error_in_exec:
#    3416         # Store formatted traceback and error details
#    3417         self.history_manager.exceptions[
#    3418             execution_count
# -> 3419         ] = self._format_exception_for_storage(result.error_in_exec)
#    3421 return result
#
# File ~/miniconda3/envs/ccam-p2/lib/python3.12/site-packages/IPython/core/interactiveshell.py:3469, in InteractiveShell._format_exception_for_storage(self, exception, filename, running_compiled_code)
#    3466         stb = evalue._render_traceback_()
#    3467     else:
#    3468         # Otherwise, use InteractiveTB to format the traceback.
# -> 3469         stb = self.InteractiveTB.structured_traceback(
#    3470             etype, evalue, tb, tb_offset=1
#    3471         )
#    3472 except Exception:
#    3473     # In case formatting fails, fallback to Python's built-in formatting.
#    3474     stb = traceback.format_exception(etype, evalue, tb)
#
# File ~/miniconda3/envs/ccam-p2/lib/python3.12/site-packages/IPython/core/ultratb.py:1193, in AutoFormattedTB.structured_traceback(self, etype, evalue, etb, tb_offset, context)
#    1191 else:
#    1192     self.tb = etb
# -> 1193 return FormattedTB.structured_traceback(
#    1194     self, etype, evalue, etb, tb_offset, context
#    1195 )
#
# File ~/miniconda3/envs/ccam-p2/lib/python3.12/site-packages/IPython/core/ultratb.py:1064, in FormattedTB.structured_traceback(self, etype, evalue, etb, tb_offset, context)
#    1061 mode = self.mode
#    1062 if mode in self.verbose_modes:
#    1063     # Verbose modes need a full traceback
# -> 1064     return VerboseTB.structured_traceback(
#    1065         self, etype, evalue, etb, tb_offset, context
#    1066     )
#    1067 elif mode == "Docs":
#    1068     # return DocTB
#    1069     return DocTB(
#    1070         theme_name=self._theme_name,
#    1071         call_pdb=self.call_pdb,
#    (...)   1079         etype, evalue, etb, tb_offset, 1
#    1080     )  # type: ignore[arg-type]
#
# File ~/miniconda3/envs/ccam-p2/lib/python3.12/site-packages/IPython/core/ultratb.py:872, in VerboseTB.structured_traceback(self, etype, evalue, etb, tb_offset, context)
#     863 def structured_traceback(
#     864     self,
#     865     etype: type,
#    (...)    869     context: int = 5,
#     870 ) -> list[str]:
#     871     """Return a nice text document describing the traceback."""
# --> 872     formatted_exceptions: list[list[str]] = self.format_exception_as_a_whole(
#     873         etype, evalue, etb, context, tb_offset
#     874     )
#     876     termsize = min(75, get_terminal_size()[0])
#     877     theme = theme_table[self._theme_name]
#
# File ~/miniconda3/envs/ccam-p2/lib/python3.12/site-packages/IPython/core/ultratb.py:757, in VerboseTB.format_exception_as_a_whole(self, etype, evalue, etb, context, tb_offset)
#     755 assert isinstance(tb_offset, int)
#     756 head = self.prepare_header(str(etype), self.long_header)
# --> 757 records = self.get_records(etb, context, tb_offset) if etb else []
#     759 frames = []
#     760 skipped = 0
#
# File ~/miniconda3/envs/ccam-p2/lib/python3.12/site-packages/IPython/core/ultratb.py:830, in VerboseTB.get_records(self, etb, context, tb_offset)
#     828 while cf is not None:
#     829     try:
# --> 830         mod = inspect.getmodule(cf.tb_frame)
#     831         if mod is not None:
#     832             mod_name = mod.__name__
#
# File ~/miniconda3/envs/ccam-p2/lib/python3.12/inspect.py:1016, in getmodule(object, _filename)
#    1013         f = getabsfile(module)
#    1014         # Always map to the name the module knows itself by
#    1015         modulesbyfile[f] = modulesbyfile[
# -> 1016             os.path.realpath(f)] = module.__name__
#    1017 if file in modulesbyfile:
#    1018     return sys.modules.get(modulesbyfile[file])
#
# File ~/miniconda3/envs/ccam-p2/lib/python3.12/posixpath.py:427, in realpath(filename, strict)
#     424     """Return the canonical path of the specified filename, eliminating any
#     425 symbolic links encountered in the path."""
#     426     filename = os.fspath(filename)
# --> 427     path, ok = _joinrealpath(filename[:0], filename, strict, {})
#     428     return abspath(path)
#
# File ~/miniconda3/envs/ccam-p2/lib/python3.12/posixpath.py:471, in _joinrealpath(path, rest, strict, seen)
#     469 newpath = join(path, name)
#     470 try:
# --> 471     st = os.lstat(newpath)
#     472 except ignored_error:
#     473     is_link = False
#
# KeyboardInterrupt:

# %%
feature_map = zz_feature_map(number_of_features)
ansatz = n_local(number_of_features, "ry", "cx", "linear")
optimizer = CRS(maxiter=50)

vqc = train_VQC(feature_map, ansatz, optimizer)
evaluate_VQC(vqc)
# Out:
# No gradient function provided, creating a gradient function. If your Sampler requires transpilation, please provide a pass manager.
#
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File ~/miniconda3/envs/ccam-p2/lib/python3.12/site-packages/IPython/core/async_helpers.py:128, in _pseudo_sync_runner(coro)
#     120 """
#     121 A runner that does not really allow async execution, and just advance the coroutine.
#     122
#    (...)    125 Credit to Nathaniel Smith
#     126 """
#     127 try:
# --> 128     coro.send(None)
#     129 except StopIteration as exc:
#     130     return exc.value
#
# File ~/miniconda3/envs/ccam-p2/lib/python3.12/site-packages/IPython/core/interactiveshell.py:3419, in InteractiveShell.run_cell_async(self, raw_cell, store_history, silent, shell_futures, transformed_cell, preprocessing_exc_tuple, cell_id)
#    3414     self.history_manager.store_output(execution_count)
#    3415     if result.error_in_exec:
#    3416         # Store formatted traceback and error details
#    3417         self.history_manager.exceptions[
#    3418             execution_count
# -> 3419         ] = self._format_exception_for_storage(result.error_in_exec)
#    3421 return result
#
# File ~/miniconda3/envs/ccam-p2/lib/python3.12/site-packages/IPython/core/interactiveshell.py:3469, in InteractiveShell._format_exception_for_storage(self, exception, filename, running_compiled_code)
#    3466         stb = evalue._render_traceback_()
#    3467     else:
#    3468         # Otherwise, use InteractiveTB to format the traceback.
# -> 3469         stb = self.InteractiveTB.structured_traceback(
#    3470             etype, evalue, tb, tb_offset=1
#    3471         )
#    3472 except Exception:
#    3473     # In case formatting fails, fallback to Python's built-in formatting.
#    3474     stb = traceback.format_exception(etype, evalue, tb)
#
# File ~/miniconda3/envs/ccam-p2/lib/python3.12/site-packages/IPython/core/ultratb.py:1193, in AutoFormattedTB.structured_traceback(self, etype, evalue, etb, tb_offset, context)
#    1191 else:
#    1192     self.tb = etb
# -> 1193 return FormattedTB.structured_traceback(
#    1194     self, etype, evalue, etb, tb_offset, context
#    1195 )
#
# File ~/miniconda3/envs/ccam-p2/lib/python3.12/site-packages/IPython/core/ultratb.py:1064, in FormattedTB.structured_traceback(self, etype, evalue, etb, tb_offset, context)
#    1061 mode = self.mode
#    1062 if mode in self.verbose_modes:
#    1063     # Verbose modes need a full traceback
# -> 1064     return VerboseTB.structured_traceback(
#    1065         self, etype, evalue, etb, tb_offset, context
#    1066     )
#    1067 elif mode == "Docs":
#    1068     # return DocTB
#    1069     return DocTB(
#    1070         theme_name=self._theme_name,
#    1071         call_pdb=self.call_pdb,
#    (...)   1079         etype, evalue, etb, tb_offset, 1
#    1080     )  # type: ignore[arg-type]
#
# File ~/miniconda3/envs/ccam-p2/lib/python3.12/site-packages/IPython/core/ultratb.py:872, in VerboseTB.structured_traceback(self, etype, evalue, etb, tb_offset, context)
#     863 def structured_traceback(
#     864     self,
#     865     etype: type,
#    (...)    869     context: int = 5,
#     870 ) -> list[str]:
#     871     """Return a nice text document describing the traceback."""
# --> 872     formatted_exceptions: list[list[str]] = self.format_exception_as_a_whole(
#     873         etype, evalue, etb, context, tb_offset
#     874     )
#     876     termsize = min(75, get_terminal_size()[0])
#     877     theme = theme_table[self._theme_name]
#
# File ~/miniconda3/envs/ccam-p2/lib/python3.12/site-packages/IPython/core/ultratb.py:757, in VerboseTB.format_exception_as_a_whole(self, etype, evalue, etb, context, tb_offset)
#     755 assert isinstance(tb_offset, int)
#     756 head = self.prepare_header(str(etype), self.long_header)
# --> 757 records = self.get_records(etb, context, tb_offset) if etb else []
#     759 frames = []
#     760 skipped = 0
#
# File ~/miniconda3/envs/ccam-p2/lib/python3.12/site-packages/IPython/core/ultratb.py:830, in VerboseTB.get_records(self, etb, context, tb_offset)
#     828 while cf is not None:
#     829     try:
# --> 830         mod = inspect.getmodule(cf.tb_frame)
#     831         if mod is not None:
#     832             mod_name = mod.__name__
#
# File ~/miniconda3/envs/ccam-p2/lib/python3.12/inspect.py:1016, in getmodule(object, _filename)
#    1013         f = getabsfile(module)
#    1014         # Always map to the name the module knows itself by
#    1015         modulesbyfile[f] = modulesbyfile[
# -> 1016             os.path.realpath(f)] = module.__name__
#    1017 if file in modulesbyfile:
#    1018     return sys.modules.get(modulesbyfile[file])
#
# File ~/miniconda3/envs/ccam-p2/lib/python3.12/posixpath.py:427, in realpath(filename, strict)
#     424     """Return the canonical path of the specified filename, eliminating any
#     425 symbolic links encountered in the path."""
#     426     filename = os.fspath(filename)
# --> 427     path, ok = _joinrealpath(filename[:0], filename, strict, {})
#     428     return abspath(path)
#
# File ~/miniconda3/envs/ccam-p2/lib/python3.12/posixpath.py:471, in _joinrealpath(path, rest, strict, seen)
#     469 newpath = join(path, name)
#     470 try:
# --> 471     st = os.lstat(newpath)
#     472 except ignored_error:
#     473     is_link = False
#
# KeyboardInterrupt:

# %%
feature_map = zz_feature_map(number_of_features)
ansatz = n_local(number_of_features, "ry", "cx", "linear")
optimizer = CRS(maxiter=50)

vqc = train_VQC(feature_map, ansatz, optimizer)
evaluate_VQC(vqc)
# Out:
# No gradient function provided, creating a gradient function. If your Sampler requires transpilation, please provide a pass manager.
#
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File ~/miniconda3/envs/ccam-p2/lib/python3.12/site-packages/IPython/core/async_helpers.py:128, in _pseudo_sync_runner(coro)
#     120 """
#     121 A runner that does not really allow async execution, and just advance the coroutine.
#     122
#    (...)    125 Credit to Nathaniel Smith
#     126 """
#     127 try:
# --> 128     coro.send(None)
#     129 except StopIteration as exc:
#     130     return exc.value
#
# File ~/miniconda3/envs/ccam-p2/lib/python3.12/site-packages/IPython/core/interactiveshell.py:3419, in InteractiveShell.run_cell_async(self, raw_cell, store_history, silent, shell_futures, transformed_cell, preprocessing_exc_tuple, cell_id)
#    3414     self.history_manager.store_output(execution_count)
#    3415     if result.error_in_exec:
#    3416         # Store formatted traceback and error details
#    3417         self.history_manager.exceptions[
#    3418             execution_count
# -> 3419         ] = self._format_exception_for_storage(result.error_in_exec)
#    3421 return result
#
# File ~/miniconda3/envs/ccam-p2/lib/python3.12/site-packages/IPython/core/interactiveshell.py:3469, in InteractiveShell._format_exception_for_storage(self, exception, filename, running_compiled_code)
#    3466         stb = evalue._render_traceback_()
#    3467     else:
#    3468         # Otherwise, use InteractiveTB to format the traceback.
# -> 3469         stb = self.InteractiveTB.structured_traceback(
#    3470             etype, evalue, tb, tb_offset=1
#    3471         )
#    3472 except Exception:
#    3473     # In case formatting fails, fallback to Python's built-in formatting.
#    3474     stb = traceback.format_exception(etype, evalue, tb)
#
# File ~/miniconda3/envs/ccam-p2/lib/python3.12/site-packages/IPython/core/ultratb.py:1193, in AutoFormattedTB.structured_traceback(self, etype, evalue, etb, tb_offset, context)
#    1191 else:
#    1192     self.tb = etb
# -> 1193 return FormattedTB.structured_traceback(
#    1194     self, etype, evalue, etb, tb_offset, context
#    1195 )
#
# File ~/miniconda3/envs/ccam-p2/lib/python3.12/site-packages/IPython/core/ultratb.py:1064, in FormattedTB.structured_traceback(self, etype, evalue, etb, tb_offset, context)
#    1061 mode = self.mode
#    1062 if mode in self.verbose_modes:
#    1063     # Verbose modes need a full traceback
# -> 1064     return VerboseTB.structured_traceback(
#    1065         self, etype, evalue, etb, tb_offset, context
#    1066     )
#    1067 elif mode == "Docs":
#    1068     # return DocTB
#    1069     return DocTB(
#    1070         theme_name=self._theme_name,
#    1071         call_pdb=self.call_pdb,
#    (...)   1079         etype, evalue, etb, tb_offset, 1
#    1080     )  # type: ignore[arg-type]
#
# File ~/miniconda3/envs/ccam-p2/lib/python3.12/site-packages/IPython/core/ultratb.py:872, in VerboseTB.structured_traceback(self, etype, evalue, etb, tb_offset, context)
#     863 def structured_traceback(
#     864     self,
#     865     etype: type,
#    (...)    869     context: int = 5,
#     870 ) -> list[str]:
#     871     """Return a nice text document describing the traceback."""
# --> 872     formatted_exceptions: list[list[str]] = self.format_exception_as_a_whole(
#     873         etype, evalue, etb, context, tb_offset
#     874     )
#     876     termsize = min(75, get_terminal_size()[0])
#     877     theme = theme_table[self._theme_name]
#
# File ~/miniconda3/envs/ccam-p2/lib/python3.12/site-packages/IPython/core/ultratb.py:757, in VerboseTB.format_exception_as_a_whole(self, etype, evalue, etb, context, tb_offset)
#     755 assert isinstance(tb_offset, int)
#     756 head = self.prepare_header(str(etype), self.long_header)
# --> 757 records = self.get_records(etb, context, tb_offset) if etb else []
#     759 frames = []
#     760 skipped = 0
#
# File ~/miniconda3/envs/ccam-p2/lib/python3.12/site-packages/IPython/core/ultratb.py:830, in VerboseTB.get_records(self, etb, context, tb_offset)
#     828 while cf is not None:
#     829     try:
# --> 830         mod = inspect.getmodule(cf.tb_frame)
#     831         if mod is not None:
#     832             mod_name = mod.__name__
#
# File ~/miniconda3/envs/ccam-p2/lib/python3.12/inspect.py:1016, in getmodule(object, _filename)
#    1013         f = getabsfile(module)
#    1014         # Always map to the name the module knows itself by
#    1015         modulesbyfile[f] = modulesbyfile[
# -> 1016             os.path.realpath(f)] = module.__name__
#    1017 if file in modulesbyfile:
#    1018     return sys.modules.get(modulesbyfile[file])
#
# File ~/miniconda3/envs/ccam-p2/lib/python3.12/posixpath.py:427, in realpath(filename, strict)
#     424     """Return the canonical path of the specified filename, eliminating any
#     425 symbolic links encountered in the path."""
#     426     filename = os.fspath(filename)
# --> 427     path, ok = _joinrealpath(filename[:0], filename, strict, {})
#     428     return abspath(path)
#
# File ~/miniconda3/envs/ccam-p2/lib/python3.12/posixpath.py:471, in _joinrealpath(path, rest, strict, seen)
#     469 newpath = join(path, name)
#     470 try:
# --> 471     st = os.lstat(newpath)
#     472 except ignored_error:
#     473     is_link = False
#
# KeyboardInterrupt:

# %%
feature_map = zz_feature_map(number_of_features)
ansatz = n_local(number_of_features, "ry", "cx", "linear")
optimizer = DIRECT_L(maxiter=50)

vqc = train_VQC(feature_map, ansatz, optimizer)
evaluate_VQC(vqc)
# Out:
# No gradient function provided, creating a gradient function. If your Sampler requires transpilation, please provide a pass manager.
#
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File ~/miniconda3/envs/ccam-p2/lib/python3.12/site-packages/IPython/core/async_helpers.py:128, in _pseudo_sync_runner(coro)
#     120 """
#     121 A runner that does not really allow async execution, and just advance the coroutine.
#     122
#    (...)    125 Credit to Nathaniel Smith
#     126 """
#     127 try:
# --> 128     coro.send(None)
#     129 except StopIteration as exc:
#     130     return exc.value
#
# File ~/miniconda3/envs/ccam-p2/lib/python3.12/site-packages/IPython/core/interactiveshell.py:3419, in InteractiveShell.run_cell_async(self, raw_cell, store_history, silent, shell_futures, transformed_cell, preprocessing_exc_tuple, cell_id)
#    3414     self.history_manager.store_output(execution_count)
#    3415     if result.error_in_exec:
#    3416         # Store formatted traceback and error details
#    3417         self.history_manager.exceptions[
#    3418             execution_count
# -> 3419         ] = self._format_exception_for_storage(result.error_in_exec)
#    3421 return result
#
# File ~/miniconda3/envs/ccam-p2/lib/python3.12/site-packages/IPython/core/interactiveshell.py:3469, in InteractiveShell._format_exception_for_storage(self, exception, filename, running_compiled_code)
#    3466         stb = evalue._render_traceback_()
#    3467     else:
#    3468         # Otherwise, use InteractiveTB to format the traceback.
# -> 3469         stb = self.InteractiveTB.structured_traceback(
#    3470             etype, evalue, tb, tb_offset=1
#    3471         )
#    3472 except Exception:
#    3473     # In case formatting fails, fallback to Python's built-in formatting.
#    3474     stb = traceback.format_exception(etype, evalue, tb)
#
# File ~/miniconda3/envs/ccam-p2/lib/python3.12/site-packages/IPython/core/ultratb.py:1193, in AutoFormattedTB.structured_traceback(self, etype, evalue, etb, tb_offset, context)
#    1191 else:
#    1192     self.tb = etb
# -> 1193 return FormattedTB.structured_traceback(
#    1194     self, etype, evalue, etb, tb_offset, context
#    1195 )
#
# File ~/miniconda3/envs/ccam-p2/lib/python3.12/site-packages/IPython/core/ultratb.py:1064, in FormattedTB.structured_traceback(self, etype, evalue, etb, tb_offset, context)
#    1061 mode = self.mode
#    1062 if mode in self.verbose_modes:
#    1063     # Verbose modes need a full traceback
# -> 1064     return VerboseTB.structured_traceback(
#    1065         self, etype, evalue, etb, tb_offset, context
#    1066     )
#    1067 elif mode == "Docs":
#    1068     # return DocTB
#    1069     return DocTB(
#    1070         theme_name=self._theme_name,
#    1071         call_pdb=self.call_pdb,
#    (...)   1079         etype, evalue, etb, tb_offset, 1
#    1080     )  # type: ignore[arg-type]
#
# File ~/miniconda3/envs/ccam-p2/lib/python3.12/site-packages/IPython/core/ultratb.py:872, in VerboseTB.structured_traceback(self, etype, evalue, etb, tb_offset, context)
#     863 def structured_traceback(
#     864     self,
#     865     etype: type,
#    (...)    869     context: int = 5,
#     870 ) -> list[str]:
#     871     """Return a nice text document describing the traceback."""
# --> 872     formatted_exceptions: list[list[str]] = self.format_exception_as_a_whole(
#     873         etype, evalue, etb, context, tb_offset
#     874     )
#     876     termsize = min(75, get_terminal_size()[0])
#     877     theme = theme_table[self._theme_name]
#
# File ~/miniconda3/envs/ccam-p2/lib/python3.12/site-packages/IPython/core/ultratb.py:757, in VerboseTB.format_exception_as_a_whole(self, etype, evalue, etb, context, tb_offset)
#     755 assert isinstance(tb_offset, int)
#     756 head = self.prepare_header(str(etype), self.long_header)
# --> 757 records = self.get_records(etb, context, tb_offset) if etb else []
#     759 frames = []
#     760 skipped = 0
#
# File ~/miniconda3/envs/ccam-p2/lib/python3.12/site-packages/IPython/core/ultratb.py:830, in VerboseTB.get_records(self, etb, context, tb_offset)
#     828 while cf is not None:
#     829     try:
# --> 830         mod = inspect.getmodule(cf.tb_frame)
#     831         if mod is not None:
#     832             mod_name = mod.__name__
#
# File ~/miniconda3/envs/ccam-p2/lib/python3.12/inspect.py:1016, in getmodule(object, _filename)
#    1013         f = getabsfile(module)
#    1014         # Always map to the name the module knows itself by
#    1015         modulesbyfile[f] = modulesbyfile[
# -> 1016             os.path.realpath(f)] = module.__name__
#    1017 if file in modulesbyfile:
#    1018     return sys.modules.get(modulesbyfile[file])
#
# File ~/miniconda3/envs/ccam-p2/lib/python3.12/posixpath.py:427, in realpath(filename, strict)
#     424     """Return the canonical path of the specified filename, eliminating any
#     425 symbolic links encountered in the path."""
#     426     filename = os.fspath(filename)
# --> 427     path, ok = _joinrealpath(filename[:0], filename, strict, {})
#     428     return abspath(path)
#
# File ~/miniconda3/envs/ccam-p2/lib/python3.12/posixpath.py:471, in _joinrealpath(path, rest, strict, seen)
#     469 newpath = join(path, name)
#     470 try:
# --> 471     st = os.lstat(newpath)
#     472 except ignored_error:
#     473     is_link = False
#
# KeyboardInterrupt:
